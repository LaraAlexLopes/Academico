# %% [markdown]
# <a href="https://colab.research.google.com/github/LaraAlexLopes/Academico/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importação de Bibliotecas**

# %%
#biblioteca de gráficos dinâmicos
# !pip install plotly --upgrade
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.6/15.6 MB 100.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.15.0
#     Uninstalling plotly-5.15.0:
#       Successfully uninstalled plotly-5.15.0
# ...

# %%
#biblioteca para carregamento de arquivos cvc
import pandas as pd
import numpy as np
import seaborn as sns #biblioteca para vizualização de gráficos
import matplotlib.pyplot as plt #biblioteca para vizualização de gráficos
import plotly.express as px

# %% [markdown]
# **Base** **de** **Dados** **de** **Crédito**

# %%
base_credit = pd.read_csv('/content/drive/MyDrive/analiseCredito/credit_data.csv')

# %%
base_credit
# Out:
#       clientid        income        age         loan  default
# 0            1  66155.925095  59.017015  8106.532131        0
# 1            2  34415.153966  48.117153  6564.745018        0
# 2            3  57317.170063  63.108049  8020.953296        0
# 3            4  42709.534201  45.751972  6103.642260        0
# 4            5  66952.688845  18.584336  8770.099235        1
# ...        ...           ...        ...          ...      ...
# 1995      1996  59221.044874  48.518179  1926.729397        0
# 1996      1997  69516.127573  23.162104  3503.176156        0
# 1997      1998  44311.449262  28.017167  5522.786693        1
# 1998      1999  43756.056605  63.971796  1622.722598        0
# 1999      2000  69436.579552  56.152617  7378.833599        0
#
# [2000 rows x 5 columns]

# %%
base_credit.head(10)
# Out:
#    clientid        income        age         loan  default
# 0         1  66155.925095  59.017015  8106.532131        0
# 1         2  34415.153966  48.117153  6564.745018        0
# 2         3  57317.170063  63.108049  8020.953296        0
# 3         4  42709.534201  45.751972  6103.642260        0
# 4         5  66952.688845  18.584336  8770.099235        1
# 5         6  24904.064140  57.471607    15.498598        0
# 6         7  48430.359613  26.809132  5722.581981        0
# 7         8  24500.141984  32.897548  2971.003310        1
# 8         9  40654.892537  55.496853  4755.825280        0
# 9        10  25075.872771  39.776378  1409.230371        0

# %%
base_credit.tail(10)
# Out:
#       clientid        income        age         loan  default
# 1990      1991  34237.575419  34.101654  2658.090632        0
# 1991      1992  26300.446554  45.539385  2317.393678        0
# 1992      1993  30803.806165  23.250084   623.024153        0
# 1993      1994  54421.410155  26.821928  3273.631823        0
# 1994      1995  24254.700791  37.751622  2225.284643        0
# 1995      1996  59221.044874  48.518179  1926.729397        0
# 1996      1997  69516.127573  23.162104  3503.176156        0
# 1997      1998  44311.449262  28.017167  5522.786693        1
# 1998      1999  43756.056605  63.971796  1622.722598        0
# 1999      2000  69436.579552  56.152617  7378.833599        0

# %%
base_credit.describe()
# Out:
#           clientid        income          age          loan      default
# count  2000.000000   2000.000000  1997.000000   2000.000000  2000.000000
# mean   1000.500000  45331.600018    40.807559   4444.369695     0.141500
# std     577.494589  14326.327119    13.624469   3045.410024     0.348624
# min       1.000000  20014.489470   -52.423280      1.377630     0.000000
# 25%     500.750000  32796.459717    28.990415   1939.708847     0.000000
# 50%    1000.500000  45789.117313    41.317159   3974.719419     0.000000
# 75%    1500.250000  57791.281668    52.587040   6432.410625     0.000000
# max    2000.000000  69995.685578    63.971796  13766.051239     1.000000

# %%
base_credit[base_credit['income'] >= 69995.685578]
# Out:
#      clientid        income        age         loan  default
# 422       423  69995.685578  52.719673  2084.370861        0

# %%
base_credit[base_credit['loan'] <= 1.377630]
# Out:
#      clientid        income        age     loan  default
# 865       866  28072.604355  54.142548  1.37763        0

# %%
base_credit[base_credit['income'] <= 20100]
# Out:
#       clientid        income        age         loan  default
# 1399      1400  20063.099584  24.278339  2495.132991        1
# 1452      1453  20014.489470  43.202204  2426.306223        0

# %%
#problemas com ponto flutuante
base_credit[base_credit['income'] <= 20014.489470]
# Out:
# Empty DataFrame
# Columns: [clientid, income, age, loan, default]
# Index: []

# %%
margem_tolerancia = 1e-6  # Define uma margem de tolerância pequena
resultado = base_credit[base_credit['income'] <= 20014.489470 + margem_tolerancia]

# %%
resultado
# Out:
#       clientid       income        age         loan  default
# 1452      1453  20014.48947  43.202204  2426.306223        0
